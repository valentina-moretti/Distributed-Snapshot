# %% [markdown]
# <a href="https://colab.research.google.com/github/valentina-moretti/Distributed-Snapshot/blob/main/C4I_Summer_days__Calculate__subset_and_plot_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ICCLIM C4I: Calculate the number of Summer Days
#
#
# Example notebook that runs ICCLIM, which is pre-installed in the notebook.
#
# The example calculates the number of summer days (SU indicator) for the dataset chosen by the user on C4I.
#
# The data is read using xarray and a plot of the time series over a specific region is generated, as well as an average spatial map. Several output types examples are shown.
#
# The dataset that is expected for this notebook are tasmax parameter (needed to calculate the SU indicator) for one specific climate model and experiment as well as one member. The time period should be continuous.
#
# To keep this example fast to run, the following period is considered: 2015-01-01 to 2019-12-31, and plots are shown over European region.
#
# ### Preparation of the needed modules

# %%
# !pip install icclim
# Out:
# Requirement already satisfied: icclim in /usr/local/lib/python3.10/dist-packages (6.4.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from icclim) (1.22.4)
# Requirement already satisfied: xarray>=2022.6 in /usr/local/lib/python3.10/dist-packages (from icclim) (2022.12.0)
# Requirement already satisfied: xclim<0.44,>=0.43 in /usr/local/lib/python3.10/dist-packages (from icclim) (0.43.0)
# Requirement already satisfied: cf-xarray>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from icclim) (0.8.4)
# Requirement already satisfied: cftime>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from icclim) (1.6.2)
# Requirement already satisfied: dask[array] in /usr/local/lib/python3.10/dist-packages (from icclim) (2022.12.1)
# Requirement already satisfied: netCDF4>=1.5.7 in /usr/local/lib/python3.10/dist-packages (from icclim) (1.6.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from icclim) (6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from icclim) (5.9.5)
# Requirement already satisfied: zarr in /usr/local/lib/python3.10/dist-packages (from icclim) (2.15.0)
# Requirement already satisfied: rechunker!=0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from icclim) (0.5.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from icclim) (2023.6.0)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.10/dist-packages (from icclim) (1.5.3)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.10/dist-packages (from icclim) (1.1.8)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.5.7->icclim) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->icclim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->icclim) (2022.7.1)
# Requirement already satisfied: mypy-extensions in /usr/local/lib/python3.10/dist-packages (from rechunker!=0.4,>=0.3->icclim) (1.0.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from xarray>=2022.6->icclim) (23.1)
# Requirement already satisfied: boltons>=20.1 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (23.0.0)
# Requirement already satisfied: bottleneck>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (1.3.7)
# Requirement already satisfied: Click>=8.1 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (8.1.4)
# Requirement already satisfied: jsonpickle in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (3.0.1)
# Requirement already satisfied: lmoments3>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (1.0.6)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (0.56.4)
# Requirement already satisfied: pint>=0.10 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (0.22)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (1.2.2)
# Requirement already satisfied: scipy>=1.2 in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (1.10.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from xclim<0.44,>=0.43->icclim) (0.13.5)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask[array]->icclim) (2.2.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[array]->icclim) (1.4.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[array]->icclim) (0.12.0)
# Requirement already satisfied: asciitree in /usr/local/lib/python3.10/dist-packages (from zarr->icclim) (0.3.3)
# Requirement already satisfied: fasteners in /usr/local/lib/python3.10/dist-packages (from zarr->icclim) (0.18)
# Requirement already satisfied: numcodecs>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from zarr->icclim) (0.11.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->icclim) (2022.10.31)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->icclim) (5.0.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from numcodecs>=0.10.0->zarr->icclim) (0.4)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[array]->icclim) (1.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pint>=0.10->xclim<0.44,>=0.43->icclim) (4.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3->icclim) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->xclim<0.44,>=0.43->icclim) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->xclim<0.44,>=0.43->icclim) (3.1.0)
# Requirement already satisfied: bokeh<3,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from dask[array]->icclim) (2.4.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from dask[array]->icclim) (3.1.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->xclim<0.44,>=0.43->icclim) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->xclim<0.44,>=0.43->icclim) (67.7.2)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->xclim<0.44,>=0.43->icclim) (0.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3,>=2.4.2->dask[array]->icclim) (8.4.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3,>=2.4.2->dask[array]->icclim) (6.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->dask[array]->icclim) (2.1.3)

# %%
# !pip install cartopy
# Out:
# Requirement already satisfied: cartopy in /usr/local/lib/python3.10/dist-packages (0.21.1)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.22.4)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.6.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.1)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.0.0->cartopy) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->cartopy) (1.16.0)

# %%
import icclim

import sys
import glob
import os
import datetime
import cftime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs

print("python: ",sys.version)
print("numpy: ", np.__version__)
print("xarray: ", xr.__version__)
print("pandas: ", pd.__version__)
print("icclim: ", icclim.__version__)
print("cftime: ", cftime.__version__)
# Out:
# WARNING:pint.util:Redefining 'percent' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining '%' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'year' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'yr' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'C' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'd' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'h' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degrees_north' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degrees_east' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining '[speed]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)
# WARNING:pint.util:Redefining '[radiation]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)
# python:  3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# numpy:  1.22.4
# xarray:  2022.12.0
# pandas:  1.5.3
# icclim:  6.4.0
# cftime:  1.6.2

# %% [markdown]
# ### Specification of the parameters and period of interest

# %%
# !wget -nc  http://esgf3.dkrz.de/thredds/fileServer/cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9i1p2f1/day/pr/gn/v20190429/pr_day_CanESM5_ssp585_r9i1p2f1_gn_20150101-21001231.nc
# Out:
# File ‘pr_day_CanESM5_ssp585_r9i1p2f1_gn_20150101-21001231.nc’ already there; not retrieving.

# %%
# studied period
import datetime
dt1 = datetime.datetime(2015,1,1)
dt2 = datetime.datetime(2100,12,31)

out_f = 'su2_icclim.nc'
import glob
filenames = glob.glob('./pr_day_CanESM5_ssp585_r9i1p2f1_gn_20150101-21001231.nc')
print(filenames)
import icclim
icclim.index(index_name='average', in_files=filenames, var_name='pr', slice_mode='JJA', time_range=[dt1, dt2], out_file=out_f, logs_verbosity='HIGH')
# Out:
# INFO:root:   ********************************************************************************************
# INFO:root:   *                                                                                          *
# INFO:root:   *          icclim                6.4.0   *
# INFO:root:   *                                                                                          *
# INFO:root:   *                                                                                          *
# INFO:root:   *          Wed Jul 19 08:43:00 2023                                                    *
# INFO:root:   *                                                                                          *
# INFO:root:   *          BEGIN EXECUTION                                                                 *
# INFO:root:   *                                                                                          *
# INFO:root:   ********************************************************************************************
# INFO:root:Processing: 0%
# ['./pr_day_CanESM5_ssp585_r9i1p2f1_gn_20150101-21001231.nc']
# /usr/local/lib/python3.10/dist-packages/icclim/generic_indices/generic_indicators.py:1267: UserWarning: Unable to infer the frequency of the time series. To mute this, set xclim's option data_validation='log'.
#   check_freq(da, src_freq, strict=True)
# /usr/local/lib/python3.10/dist-packages/xclim/core/cfchecks.py:41: UserWarning: Variable does not have a `cell_methods` attribute.
#   _check_cell_methods(
# /usr/local/lib/python3.10/dist-packages/xclim/core/cfchecks.py:45: UserWarning: Variable does not have a `standard_name` attribute.
#   check_valid(vardata, "standard_name", data["standard_name"])
# INFO:root:Processing: 100%
# INFO:root:   ********************************************************************************************
# INFO:root:   *                                                                                          *
# INFO:root:   *          icclim                6.4.0   *
# INFO:root:   *                                                                                          *
# INFO:root:   *                                                                                          *
# INFO:root:   *          Wed Jul 19 08:43:15 2023                                                    *
# INFO:root:   *                                                                                          *
# INFO:root:   *          END EXECUTION                                                                   *
# INFO:root:   *                                                                                          *
# INFO:root:   *          CP SECS = 23.681568961                                                            *
# INFO:root:   *                                                                                          *
# INFO:root:   ********************************************************************************************
# <xarray.Dataset>
# Dimensions:      (lat: 64, lon: 128, time: 86, bounds: 2)
# Coordinates:
#   * lat          (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon          (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#   * time         (time) object 2015-07-16 12:00:00 ... 2100-07-16 12:00:00
#   * bounds       (bounds) int64 0 1
# Data variables:
#     average      (time, lat, lon) float32 dask.array<chunksize=(1, 32, 64), meta=np.ndarray>
#     time_bounds  (time, bounds) object 2015-06-01 00:00:00 ... 2100-08-31 00:...
# Attributes:
#     title:        precipitation_flux
#     references:   icclim
#     institution:  Climate impact portal (https://climate4impact.eu)
#     history:      2019-05-30T00:40:24Z altered by CMOR: Reordered dimensions,...
#     source:
#     Conventions:  CF-1.6

# %% [markdown]
# ### Plot preparation

# %%
with xr.open_dataset(out_f, decode_times=False) as ds:
    su_xr = ds
    ds['time'] = xr.decode_cf(ds).time

print(su_xr)

# Select a single x,y combination from the data
longitude = su_xr["average"]["lon"].sel(lon=3.5, method='nearest')
latitude = su_xr["average"]["lat"].sel(lat=44.2, method='nearest')

print("Long, Lat values:", longitude, latitude)
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 64, lon: 128, time: 86, bounds: 2)
# Coordinates:
#   * lat          (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon          (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#   * time         (time) object 2015-07-16 12:00:00 ... 2100-07-16 12:00:00
#   * bounds       (bounds) int64 0 1
# Data variables:
#     average      (time, lat, lon) float32 ...
#     time_bounds  (time, bounds) int64 ...
# Attributes:
#     title:        precipitation_flux
#     references:   icclim
#     institution:  Climate impact portal (https://climate4impact.eu)
#     history:      2019-05-30T00:40:24Z altered by CMOR: Reordered dimensions,...
#     source:
#     Conventions:  CF-1.6
# Long, Lat values: <xarray.DataArray 'lon' ()>
# array(2.8125)
# Coordinates:
#     lon      float64 2.812
# Attributes:
#     bounds:         lon_bnds
#     units:          degrees_east
#     axis:           X
#     long_name:      Longitude
#     standard_name:  longitude <xarray.DataArray 'lat' ()>
# array(43.25419467)
# Coordinates:
#     lat      float64 43.25
# Attributes:
#     bounds:         lat_bnds
#     units:          degrees_north
#     axis:           Y
#     long_name:      Latitude
#     standard_name:  latitude

# %% [markdown]
# ### Subset and Plot

# %%
# !pip install nc-time-axis
# Out:
# Requirement already satisfied: nc-time-axis in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: cftime>=1.5 in /usr/local/lib/python3.10/dist-packages (from nc-time-axis) (1.6.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from nc-time-axis) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nc-time-axis) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc-time-axis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->nc-time-axis) (1.16.0)

# %%
# !pip install nc_time_axis
import nc_time_axis
# Out:
# Requirement already satisfied: nc_time_axis in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: cftime>=1.5 in /usr/local/lib/python3.10/dist-packages (from nc_time_axis) (1.6.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from nc_time_axis) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nc_time_axis) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nc_time_axis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->nc_time_axis) (1.16.0)

# %%
# Slice the data spatially using a single lat/lon point
one_point = su_xr["average"].sel(lat=latitude, lon=longitude)

# Use xarray to create a quick time series plot
one_point.plot.line()
plt.show()

# %%
# You can clean up your plot as you wish using standard matplotlib approaches
f, ax = plt.subplots(figsize=(12, 6))
one_point.plot.line(hue='lat',
                    marker="o",
                    ax=ax,
                    color="grey",
                    markerfacecolor="purple",
                    markeredgecolor="purple")
ax.set(title="Time Series For a Single Lat / Lon Location")

# Uncomment the line below if you wish to export the figure as a .png file
# plt.savefig("single_point_timeseries.png")
plt.show()

# %%
# Convert to dataframe -- then this can easily be exported to a csv
one_point_df = one_point.to_dataframe()
# View just the first 5 rows of the data
one_point_df.head()

# Export data to .csv file
#one_point_df.to_csv("one-location.csv")
# Out:
#                            lat     lon   average
# time
# 2015-07-16 12:00:00  43.254195  2.8125  0.000018
# 2016-07-16 12:00:00  43.254195  2.8125  0.000016
# 2017-07-16 12:00:00  43.254195  2.8125  0.000009
# 2018-07-16 12:00:00  43.254195  2.8125  0.000015
# 2019-07-16 12:00:00  43.254195  2.8125  0.000007

# %%
# Time subsetting: this is just an example on how to do it
start_date = "2015-01-01"
end_date = "2100-12-31"

su = su_xr["average"].sel(time=slice(start_date, end_date))

# %%
# Quickly plot the data using xarray.plot()
su.plot(x="lon",
        y="lat",
        col='time',
        col_wrap=1)

plt.suptitle("Two Time Steps of Summer Days", y=1.03)
plt.show()

# %%
# Set spatial extent and centre
central_lat = 47.0
central_lon = 1.0
extent = [-30, 30, 30, 56]  # Western Europe

# Calculate time average
su_avg = su.mean(dim='time', keep_attrs=True)

# Set plot projection
map_proj = ccrs.AlbersEqualArea(central_longitude=central_lon,
                                central_latitude=central_lat)

# Define plot
f, ax = plt.subplots(figsize=(14, 6),
                     subplot_kw={'projection': map_proj})

# Plot data with proper colormap scale range
levels = np.arange(0, 90, 5)
p = su_avg.plot(levels=levels,
                cmap='RdBu_r',
                transform=ccrs.PlateCarree())

# Plot information
plt.suptitle("Two Time Steps of Europe Summer Days", y=1)

# Add the coastlines to axis and set extent
ax.coastlines()
ax.gridlines()
ax.set_extent(extent)

# Save plot as png
plt.savefig('c4i_su_icclim.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d474aafcd841> in <cell line: 7>()
#       5
#       6 # Calculate time average
# ----> 7 su_avg = su.mean(dim='time', keep_attrs=True)
#       8
#       9 # Set plot projection
#
# NameError: name 'su' is not defined

# %%
# Re-order longitude so that there is no blank line at 0 deg because 0 deg is within our spatial selection
su_avg.coords['lon'] = (su_avg.coords['lon'] + 180) % 360 - 180
su_avg = su_avg.sortby(su_avg.lon)

# Define plot
f, ax = plt.subplots(figsize=(14, 6),
                     subplot_kw={'projection': map_proj})

# Define colorscale
levels = np.arange(0, 90, 15)

# Contours lines
p = su_avg.plot.contour(levels=levels,
                         colors='k',
                         linewidths=0.5,
                         transform=ccrs.PlateCarree())

# Contour filled colors
p = su_avg.plot.contourf(levels=levels,
                          cmap='RdBu_r',
                          extend='both',
                          transform=ccrs.PlateCarree())

# Plot information
plt.suptitle("Two Time Steps of Europe Summer Days", y=1)

# Add the coastlines to axis and set extent
ax.coastlines()
ax.gridlines()
ax.set_extent(extent)

# Save plot as png
plt.savefig('c4i_su_contours_icclim.png')
